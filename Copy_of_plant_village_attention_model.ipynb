# %% [markdown]
# <a href="https://colab.research.google.com/github/Rula-Islait/Research/blob/main/Copy_of_plant_village_attention_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import tensorflow_datasets as tfds

# %%
dataset, info = tfds.load("plant_village", as_supervised=True, with_info=True, split=["train"])
num_classes = info.features["label"].num_classes
# Out:
# Downloading and preparing dataset 827.82 MiB (download: 827.82 MiB, generated: 815.37 MiB, total: 1.60 GiB) to /root/tensorflow_datasets/plant_village/1.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/54303 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/plant_village/incomplete.1L3HB1_1.0.2/plant_village-train.tfrecord*...:   …
# Dataset plant_village downloaded and prepared to /root/tensorflow_datasets/plant_village/1.0.2. Subsequent calls will reuse this data.

# %%
IMG_SIZE = 128

def preprocess(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE)) / 255.0
    label = tf.one_hot(label, num_classes)
    return image, label

# %%
train_dataset = dataset[0].map(preprocess).shuffle(1000).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
class SequentialAttention(layers.Layer):
    def __init__(self, filters):
        super(SequentialAttention, self).__init__()
        self.conv = layers.Conv2D(filters, (1, 1), activation='sigmoid')

    def call(self, inputs):
        attention_map = self.conv(inputs)
        return inputs * attention_map

# %%
class ReverseAttention(layers.Layer):
    def __init__(self, filters):
        super(ReverseAttention, self).__init__()
        self.conv = layers.Conv2D(filters, (1, 1), activation='sigmoid')

    def call(self, inputs):
        attention_map = self.conv(inputs)
        return inputs - (inputs * attention_map)

# %%
class DynamicAttention(layers.Layer):
    def __init__(self, filters):
        super(DynamicAttention, self).__init__()
        self.fc = layers.Dense(filters, activation='sigmoid')

    def call(self, inputs):
        x = tf.reduce_mean(inputs, axis=[1, 2], keepdims=True)
        attention = self.fc(x)
        return inputs * attention

# %%
from tensorflow.keras import layers, models

def build_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    x = inputs

    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = ReverseAttention(128)(x)

    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = DynamicAttention(256)(x)

    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = SequentialAttention(512)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# %%
input_shape = (IMG_SIZE, IMG_SIZE, 3)
model = build_model(input_shape, num_classes)

# %%
optimizer = Adam(learning_rate=0.0003)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=train_dataset,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 358s 187ms/step - accuracy: 0.5419 - loss: 1.7272 - val_accuracy: 0.9008 - val_loss: 0.3193 - learning_rate: 3.0000e-04
# Epoch 2/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 169ms/step - accuracy: 0.8787 - loss: 0.4076 - val_accuracy: 0.8578 - val_loss: 0.5499 - learning_rate: 3.0000e-04
# Epoch 3/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 169ms/step - accuracy: 0.9315 - loss: 0.2249 - val_accuracy: 0.7853 - val_loss: 0.8871 - learning_rate: 3.0000e-04
# Epoch 4/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 299s 176ms/step - accuracy: 0.9515 - loss: 0.1620 - val_accuracy: 0.8098 - val_loss: 1.0144 - learning_rate: 3.0000e-04
# Epoch 5/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 169ms/step - accuracy: 0.9648 - loss: 0.1187 - val_accuracy: 0.9449 - val_loss: 0.2046 - learning_rate: 3.0000e-04
# Epoch 6/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 168ms/step - accuracy: 0.9710 - loss: 0.0960 - val_accuracy: 0.9668 - val_loss: 0.1092 - learning_rate: 3.0000e-04
# Epoch 7/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 288s 170ms/step - accuracy: 0.9763 - loss: 0.0778 - val_accuracy: 0.9703 - val_loss: 0.0936 - learning_rate: 3.0000e-04
# Epoch 8/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 288s 169ms/step - accuracy: 0.9801 - loss: 0.0689 - val_accuracy: 0.9848 - val_loss: 0.0483 - learning_rate: 3.0000e-04
# Epoch 9/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 322s 169ms/step - accuracy: 0.9817 - loss: 0.0621 - val_accuracy: 0.9270 - val_loss: 0.2543 - learning_rate: 3.0000e-04
# Epoch 10/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 169ms/step - accuracy: 0.9844 - loss: 0.0523 - val_accuracy: 0.8422 - val_loss: 0.9587 - learning_rate: 3.0000e-04
# Epoch 11/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 169ms/step - accuracy: 0.9837 - loss: 0.0554 - val_accuracy: 0.8362 - val_loss: 0.8888 - learning_rate: 3.0000e-04
# Epoch 12/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 299s 176ms/step - accuracy: 0.9863 - loss: 0.0454 - val_accuracy: 0.9762 - val_loss: 0.0752 - learning_rate: 3.0000e-04
# Epoch 13/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 169ms/step - accuracy: 0.9874 - loss: 0.0421 - val_accuracy: 0.9854 - val_loss: 0.0469 - learning_rate: 3.0000e-04
# Epoch 14/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 335s 176ms/step - accuracy: 0.9889 - loss: 0.0365 - val_accuracy: 0.9919 - val_loss: 0.0253 - learning_rate: 3.0000e-04
# Epoch 15/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 300s 176ms/step - accuracy: 0.9872 - loss: 0.0454 - val_accuracy: 0.9965 - val_loss: 0.0123 - learning_rate: 3.0000e-04
# Epoch 16/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 299s 176ms/step - accuracy: 0.9904 - loss: 0.0344 - val_accuracy: 0.9904 - val_loss: 0.0301 - learning_rate: 3.0000e-04
# Epoch 17/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 310s 169ms/step - accuracy: 0.9912 - loss: 0.0324 - val_accuracy: 0.9043 - val_loss: 0.4138 - learning_rate: 3.0000e-04
# Epoch 18/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 168ms/step - accuracy: 0.9925 - loss: 0.0271 - val_accuracy: 0.9603 - val_loss: 0.1810 - learning_rate: 3.0000e-04
# Epoch 19/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 287s 169ms/step - accuracy: 0.9939 - loss: 0.0232 - val_accuracy: 0.9959 - val_loss: 0.0134 - learning_rate: 3.0000e-04
# Epoch 20/20
# 1697/1697 ━━━━━━━━━━━━━━━━━━━━ 286s 168ms/step - accuracy: 0.9930 - loss: 0.0253 - val_accuracy: 0.9614 - val_loss: 0.1548 - learning_rate: 3.0000e-04

# %%
test_loss, test_acc = model.evaluate(train_dataset, verbose=2)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 1697/1697 - 70s - 41ms/step - accuracy: 0.9965 - loss: 0.0123
# Test Accuracy: 99.65%

# %%
print(f"Test loss: {test_loss}")
# Out:
# Test Accuracy: 0.012257931753993034

# %%
model.save("plant_village_attention_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
